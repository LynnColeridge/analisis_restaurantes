# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
data = pd.read_csv("Top250.csv")

# %%
data.head(10)
# Out:
#    Rank    Restaurant                                            Content  \
# 0     1    McDonald's                                                NaN
# 1     2     Starbucks                                                NaN
# 2     3   Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4     Taco Bell                                                NaN
# 4     5   Burger King                                                NaN
# 5     6        Subway                                                NaN
# 6     7       Wendy's                                                NaN
# 7     8       Dunkin'  Dunkin' dropped "Donuts" from its name and rep...
# 8     9      Domino's                                                NaN
# 9    10  Panera Bread                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412      4.9%  13846     -0.5%          NaN       Quick Service & Burger
# ...

# %%
data.shape
# Out:
# (250, 9)

# %%
data.columns
# Out:
# Index(['Rank', 'Restaurant', 'Content', 'Sales', 'YOY_Sales', 'Units',
#        'YOY_Units', 'Headquarters', 'Segment_Category'],
#       dtype='object')

# %%
# tomar el tipo de restaurante como indice
tipo = data.set_index('Segment_Category')

# %%
tipo
# Out:
#                              Rank           Restaurant  \
# Segment_Category
# Quick Service & Burger          1           McDonald's
# Quick Service & Coffee Cafe     2            Starbucks
# Quick Service & Chicken         3          Chick-fil-A
# Quick Service & Mexican         4            Taco Bell
# Quick Service & Burger          5          Burger King
# ...                           ...                  ...
# Varied Menu                   246      Rainforest Cafe
# Chicken                       247                  PDQ
# Mexican                       248        Lupe Tortilla
# Burger                        249  Cook-Out Restaurant
# Chicken                       250             Jollibee
#
#                                                                        Content  \
# Segment_Category
# Quick Service & Burger                                                     NaN
# Quick Service & Coffee Cafe                                                NaN
# ...

# %%
# crear un dataframe de los restaurantes que son solo tipo de pollo
pollo = tipo.loc['Chicken', :]

# %%
pollo.shape
# Out:
# (7, 8)

# %%
# contar los elementos que son pollo en la columna de segmento de categorias del dataframe original
sum(data.Segment_Category == 'Chicken')
# Out:
# 7

# %%
# agrupar por segmento de categoria, cuenta cuantas categorias unicas hay y cuantos registros cuenta en cada columna
data.groupby('Segment_Category').count()
# Out:
#                                  Rank  Restaurant  Content  Sales  YOY_Sales  \
# Segment_Category
# Asian                               3           3        0      3          3
# Asian/Noodle                        3           3        0      3          3
# BBQ                                 7           7        1      7          7
# Bakery Cafe                         8           8        2      8          8
# Burger                             10          10        1     10         10
# Casual Dining & Asian               1           1        0      1          1
# Casual Dining & Italian/Pizza       4           4        1      4          4
# Casual Dining & Seafood             2           2        0      2          2
# Casual Dining & Sports Bar          3           3        0      3          3
# Casual Dining & Steak               4           4        0      4          4
# Casual Dining & Varied Menu         9           9        2      9          9
# ...

# %%
burger = tipo.loc['Burger', :]
burger.shape
# Out:
# (10, 8)

# %%
# traer todos los registros de la categoria burger que tenga headquarters
tipo.loc['Burger', :]
# Out:
#                   Rank             Restaurant  \
# Segment_Category
# Burger             118            Krystal Co.
# Burger             134                 Jack's
# Burger             139     Rally's Hamburgers
# Burger             147            Smashburger
# Burger             160  A&W All-American Food
# Burger             183            Fuddruckers
# Burger             190            Farmer Boys
# Burger             211        Wayback Burgers
# Burger             234               BurgerFi
# Burger             249    Cook-Out Restaurant
#
#                                                             Content  Sales  \
# Segment_Category
# Burger                                                          NaN    343
# Burger                                                          NaN    290
# Burger                                                          NaN    275
# Burger                                                          NaN    265
# ...

# %%
tipo
# Out:
#                              Rank           Restaurant  \
# Segment_Category
# Quick Service & Burger          1           McDonald's
# Quick Service & Coffee Cafe     2            Starbucks
# Quick Service & Chicken         3          Chick-fil-A
# Quick Service & Mexican         4            Taco Bell
# Quick Service & Burger          5          Burger King
# ...                           ...                  ...
# Varied Menu                   246      Rainforest Cafe
# Chicken                       247                  PDQ
# Mexican                       248        Lupe Tortilla
# Burger                        249  Cook-Out Restaurant
# Chicken                       250             Jollibee
#
#                                                                        Content  \
# Segment_Category
# Quick Service & Burger                                                     NaN
# Quick Service & Coffee Cafe                                                NaN
# ...

# %%
# traer el registro del restaurante Chick-fil-A
np.where(data['Restaurant'] == 'Chick-fil-A') # ubicar el indice del registro del restaurante
# Out:
# (array([2], dtype=int64),)

# %%
# acceder al regristro por su indice obtenido  en la  instruccion anterior
data.iloc[2, :]
# Out:
# Rank                                                                3
# Restaurant                                                Chick-fil-A
# Content             While Popeyes got a lot of the chicken buzz in...
# Sales                                                           11320
# YOY_Sales                                                       13.0%
# Units                                                            2470
# YOY_Units                                                        5.0%
# Headquarters                                                      NaN
# Segment_Category                              Quick Service & Chicken
# Name: 2, dtype: object

# %%
# encontrar los indices de los registros de los restaurantes de hamburguesas
indice_burgers = np.where(data['Segment_Category'] == 'Burger')
indice_burgers
# Out:
# (array([117, 133, 138, 146, 159, 182, 189, 210, 233, 248], dtype=int64),)

# %%
# buscar el registro de todos los restaurantes de hamburguesas
data.iloc[indice_burgers]
# Out:
#      Rank             Restaurant  \
# 117   118            Krystal Co.
# 133   134                 Jack's
# 138   139     Rally's Hamburgers
# 146   147            Smashburger
# 159   160  A&W All-American Food
# 182   183            Fuddruckers
# 189   190            Farmer Boys
# 210   211        Wayback Burgers
# 233   234               BurgerFi
# 248   249    Cook-Out Restaurant
#
#                                                Content  Sales YOY_Sales  \
# 117                                                NaN    343     -9.0%
# 133                                                NaN    290      9.8%
# 138                                                NaN    275     -3.5%
# 146                                                NaN    265     -6.5%
# 159  The chain's 100th birthday found it working to...    227      1.8%
# 182                                                NaN    185    -15.8%
# 189                                                NaN    179      1.7%
# ...

# %%
# recuperar la columna Restaurant
data['Restaurant']
# Out:
# 0               McDonald's
# 1                Starbucks
# 2              Chick-fil-A
# 3                Taco Bell
# 4              Burger King
#               ...
# 245        Rainforest Cafe
# 246                    PDQ
# 247          Lupe Tortilla
# 248    Cook-Out Restaurant
# 249               Jollibee
# Name: Restaurant, Length: 250, dtype: object

# %%
data.Sales.mean()
# Out:
# 1242.74

# %%
data['Sales'].mean()
# Out:
# 1242.74

# %%
sum = 0
for ei in data['Sales']:
    sum = sum + ei
    
print(sum/len(data['Sales']))
# Out:
# 1242.74

# %%
data['Sales'].describe()
# Out:
# count      250.00000
# mean      1242.74000
# std       3365.22882
# min        126.00000
# 25%        181.00000
# 50%        330.00000
# 75%        724.75000
# max      40412.00000
# Name: Sales, dtype: float64

# %%
# ver cual es el registro con la mayor venta
data.loc[:,'Sales'] == 40412
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# Name: Sales, Length: 250, dtype: bool

# %%
# recuperar el registro del restaurante con la mayor venta
data.iloc[0, :]
# Out:
# Rank                                     1
# Restaurant                      McDonald's
# Content                                NaN
# Sales                                40412
# YOY_Sales                             4.9%
# Units                                13846
# YOY_Units                            -0.5%
# Headquarters                           NaN
# Segment_Category    Quick Service & Burger
# Name: 0, dtype: object

# %%
ventas_mayores = np.where(data['Sales'] == 40412)

# %%
data.iloc[ventas_mayores]
# Out:
#    Rank  Restaurant Content  Sales YOY_Sales  Units YOY_Units Headquarters  \
# 0     1  McDonald's     NaN  40412      4.9%  13846     -0.5%          NaN
#
#          Segment_Category
# 0  Quick Service & Burger

# %%
# guardar el indice del restaurante con la menor venta
venta_menores = np.where(data['Sales'] == 126)
venta_menores
# Out:
# (array([248, 249], dtype=int64),)

# %%
data.iloc[venta_menores]
# Out:
#      Rank           Restaurant Content  Sales YOY_Sales  Units YOY_Units  \
# 248   249  Cook-Out Restaurant     NaN    126     10.1%    270      7.1%
# 249   250             Jollibee     NaN    126     15.2%     40     11.1%
#
#     Headquarters Segment_Category
# 248          NaN           Burger
# 249          NaN          Chicken

# %%
# obtener los restaurantes con las ventas menores
data.loc[venta_menores, 'Restaurant']
# Out:
# 248    Cook-Out Restaurant
# 249               Jollibee
# Name: Restaurant, dtype: object
